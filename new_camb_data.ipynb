# %%
import camb
import numpy as np
import matplotlib.pyplot as plt

# %%
params       = np.load('CL_data/parameter_test.npy')
cls_unlensed = np.load('CL_data/unlensed_CL.npy')
cls_lensed   = np.load('CL_data/lensed_CL.npy')

print(np.max(params[:,0]), "max H0")      # planck: 67.4
print(np.max(params[:,1]), "max ombh2")   # planck: 0.0224
print(np.max(params[:,2]), "max omch2\n") # planck: 0.120

print(np.min(params[:,0]), "min H0")
print(np.min(params[:,1]), "min ombh2")
print(np.min(params[:,2]), "min omch2\n")
# Out:
# (100, 4998)
# 89.3934460862422 max H0
# 0.026925656725600128 max ombh2
# 0.13938550241198827 max omch2
#
# 50.02602040793274 min H0
# 0.015046637557001077 min ombh2
# 0.08063408296798269 min omch2

# %%
max_H0 = 90
min_H0 = 50

max_ombh2 = 0.035
min_ombh2 = 0.015

max_omch2 = 0.016
min_omch2 = 0.08


params =       []
cls_lensed =   []
cls_unlensed = []

n_data = 400

for i in range(n_data):
    print(f"running {i+1}/{400}")
    # generate params
    
    _H0 =    np.random.uniform(low = min_H0, high = max_H0)
    _ombh2 = np.random.uniform(low = min_ombh2, high = max_ombh2)
    _omch2 = np.random.uniform(low = min_omch2, high = max_omch2)
    
    params.append([_H0, _ombh2, _omch2])
    
    # run CAMB
    
    pars = camb.set_params(H0 = _H0, ombh2 = _ombh2, omch2 = _omch2, lmax=5000)
    results = camb.get_results(pars)
    powers =results.get_cmb_power_spectra(pars, CMB_unit='muK')
    
    cls_lensed.append(powers['total'][2:5000, 0])
    cls_unlensed.append(powers['unlensed_total'][2:5000, 0])
    
params = np.array(params)
cls_lensed = np.array(cls_lensed)
cls_unlensed = np.array(cls_unlensed)
# Out:
# running 1/400
# running 2/400
# running 3/400
# running 4/400
# running 5/400
# running 6/400
# running 7/400
# running 8/400
# running 9/400
# running 10/400
# running 11/400
# running 12/400
# running 13/400
# running 14/400
# running 15/400
# running 16/400
# running 17/400
# running 18/400
# running 19/400
# running 20/400
# running 21/400
# running 22/400
# running 23/400
# running 24/400
# running 25/400
# running 26/400
# running 27/400
# running 28/400
# running 29/400
# running 30/400
# running 31/400
# running 32/400
# running 33/400
# running 34/400
# running 35/400
# running 36/400
# running 37/400
# running 38/400
# running 39/400
# running 40/400
# running 41/400
# running 42/400
# running 43/400
# running 44/400
# running 45/400
# running 46/400
# running 47/400
# running 48/400
# running 49/400
# running 50/400
# running 51/400
# running 52/400
# running 53/400
# running 54/400
# running 55/400
# running 56/400
# running 57/400
# running 58/400
# running 59/400
# running 60/400
# running 61/400
# running 62/400
# running 63/400
# running 64/400
# running 65/400
# running 66/400
# running 67/400
# running 68/400
# running 69/400
# running 70/400
# running 71/400
# running 72/400
# running 73/400
# running 74/400
# running 75/400
# running 76/400
# running 77/400
# running 78/400
# running 79/400
# running 80/400
# running 81/400
# running 82/400
# running 83/400
# running 84/400
# running 85/400
# running 86/400
# running 87/400
# running 88/400
# running 89/400
# running 90/400
# running 91/400
# running 92/400
# running 93/400
# running 94/400
# running 95/400
# running 96/400
# running 97/400
# running 98/400
# running 99/400
# running 100/400
# running 101/400
# running 102/400
# running 103/400
# running 104/400
# running 105/400
# running 106/400
# running 107/400
# running 108/400
# running 109/400
# running 110/400
# running 111/400
# running 112/400
# running 113/400
# running 114/400
# running 115/400
# running 116/400
# running 117/400
# running 118/400
# running 119/400
# running 120/400
# running 121/400
# running 122/400
# running 123/400
# running 124/400
# running 125/400
# running 126/400
# running 127/400
# running 128/400
# running 129/400
# running 130/400
# running 131/400
# running 132/400
# running 133/400
# running 134/400
# running 135/400
# running 136/400
# running 137/400
# running 138/400
# running 139/400
# running 140/400
# running 141/400
# running 142/400
# running 143/400
# running 144/400
# running 145/400
