# %%
from pysr import PySRRegressor, TemplateExpressionSpec

import matplotlib.pyplot as plt
import numpy as np

import camb
# Out:
# Detected IPython. Loading juliacall extension. See https://juliapy.github.io/PythonCall.jl/stable/compat/#IPython

# %%
# Load Data

pars     = np.load('CL_data/parameter_pysr.npy')  # [H0, ombh2, omch2 ] x 100
lensed   = np.load('CL_data/lensed_pysr.npy')     # [C_2, ..., C_5000] x 100 (lensed)
unlensed = np.load('CL_data/unlensed_pysr.npy')     # [C_2, ..., C_5000] x 100 (unlensed)

# %%
past_ells = 1000
n_ells = 4998 - past_ells

# Truncate to ignore first 1000 l's
y_pysr = lensed[:, past_ells:]/unlensed[:, past_ells:]

def moving_average(x):
    val = np.convolve(x, np.ones(500), 'valid') / 500
    return val

# Smoothing the Lensing Tail for Training
do_smoothing = True

if do_smoothing:
    y_pysr[:, 249:-250] = np.apply_along_axis(moving_average, axis = 1, arr = y_pysr[:, :])

# Reformatting data
y_pysr = y_pysr.reshape(-1)
# y_pysr : [par1_c502, par1_c503, ..., par1_c5000, par2_c502, ..., par299_c502, ..., par299_c5000]

# %%
# Reformatting data
X_ells = np.array([ell for ell in range(past_ells + 2, 5000)])
pars_pysr = pars[:]
X_pysr = np.zeros((y_pysr.shape[0], 3 + 1))

# %%
# Reformatting data
for i in range(100):
    X_pysr[n_ells*i:n_ells*(i+1), :3] = np.tile(pars[i], n_ells).reshape(n_ells, -1)
    X_pysr[n_ells*i:n_ells*(i+1), -1] = X_ells

# make x3 = ombh2 + omch2 = om0h2
X_pysr[:, 2] = X_pysr[:, 1] + X_pysr[:, 2]

# %%
# Template Function

template = TemplateExpressionSpec(
    expressions = ["g"],
    variable_names = ["x1", "x2", "x3", "x4"],
    parameters = {"beta": 3},
    combine = "1 + (beta[1]*(x4/beta[2])^(g(x2, x3)) - 1)*(1 + exp(-(x4-beta[3]*2000)/100))^-1"
)

# PySR Model

model = PySRRegressor(
    niterations = 100,
    binary_operators = ["+", "-", "*", "pow"],
    constraints = {'pow': (4, 1), "*": (4, 4)},
    batching = True, 
    batch_size = 10000, 
    maxsize = 30,
    populations = 20,
    expression_spec = template,
    complexity_of_variables = 2,
    procs = 4
)

# %%
# Train

model.fit(X_pysr, y_pysr)
# Out:
# /opt/anaconda3/envs/pysr_env/lib/python3.13/site-packages/pysr/sr.py:2774: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# Compiling Julia backend...
# [ Info: Started!
# Expressions evaluated per second: 0.000e+00
# Progress: 0 / 2000 total iterations (0.000%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 9.990e-01
# Progress: 1 / 2000 total iterations (0.050%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 8           4.860e-01  1.993e+00  ╭ g = -0.46423 - #2
#                                   ├ h = -0.46423 + #2
#                                   ├ p1 = [-0.91324]
#                                   ╰ alphas = [0.43597, -0.88044, -1.9027]
# 16          8.788e-02  2.138e-01  ╭ g = (((-0.28088 - #2) + (0.41255 - #2)) + #1) - #2
#                                   ├ h = -0.29474
#                                   ├ p1 = [-0.3148]
#                                   ╰ alphas = [-0.93287, 1.0192, -1.8959]
# 18          7.831e-02  5.760e-02  ╭ g = ((((1.8966 - #2) + (2.5912 - #2)) + #1) - #2) - -1.92
#                                   ├ h = -0.56223
#                                   ├ p1 = [-0.82666]
#                                   ╰ alphas = [-0.87771, 0.92835, -2.0644]
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.670e+00
# Progress: 2 / 2000 total iterations (0.100%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 8           4.860e-01  1.993e+00  ╭ g = -0.46423 - #2
#                                   ├ h = -0.46423 + #2
#                                   ├ p1 = [-0.91324]
#                                   ╰ alphas = [0.43597, -0.88044, -1.9027]
# 16          8.788e-02  2.138e-01  ╭ g = (((-0.28088 - #2) + (0.41255 - #2)) + #1) - #2
#                                   ├ h = -0.29474
#                                   ├ p1 = [-0.3148]
#                                   ╰ alphas = [-0.93287, 1.0192, -1.8959]
# 18          7.831e-02  5.760e-02  ╭ g = ((((1.8966 - #2) + (2.5912 - #2)) + #1) - #2) - -1.92
#                                   ├ h = -0.56223
#                                   ├ p1 = [-0.82666]
#                                   ╰ alphas = [-0.87771, 0.92835, -2.0644]
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.280e+01
# Progress: 7 / 2000 total iterations (0.350%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 8           4.860e-01  1.993e+00  ╭ g = -0.46423 - #2
#                                   ├ h = -0.46423 + #2
#                                   ├ p1 = [-0.91324]
#                                   ╰ alphas = [0.43597, -0.88044, -1.9027]
# 15          2.597e-01  8.955e-02  ╭ g = 0.64972 - ((-0.35134 + #2) - -0.93304)
#                                   ├ h = (#2 - #1) - -1.6857
#                                   ├ p1 = [-1.5259]
#                                   ╰ alphas = [-0.86885, 0.62923, 0.091147]
# 16          8.788e-02  1.084e+00  ╭ g = (((-0.28088 - #2) + (0.41255 - #2)) + #1) - #2
#                                   ├ h = -0.29474
#                                   ├ p1 = [-0.3148]
#                                   ╰ alphas = [-0.93287, 1.0192, -1.8959]
# 18          7.831e-02  5.760e-02  ╭ g = ((((1.8966 - #2) + (2.5912 - #2)) + #1) - #2) - -1.92
#                                   ├ h = -0.56223
#                                   ├ p1 = [-0.82666]
#                                   ╰ alphas = [-0.87771, 0.92835, -2.0644]
# 20          7.077e-02  5.065e-02  ╭ g = #1 + -3.2155
#                                   ├ h = (((-0.16103 - #2) + #2) + -1.203) + ((-1.3576 - #2) + 0....
#                                   21396)
#                                   ├ p1 = [-1.5189]
#                                   ╰ alphas = [-0.9129, -0.92421, -0.88949]
# 22          6.719e-02  2.592e-02  ╭ g = (#1 + -1.1537) - 2.0545
#                                   ├ h = ((-0.17974 - (#2 + #2)) + -1.2215) + ((-1.3763 - #2) + 0...
#                                   .19524)
#                                   ├ p1 = [-1.5276]
#                                   ╰ alphas = [-0.90507, -0.91682, -0.87844]
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.500e+01
# Progress: 10 / 2000 total iterations (0.500%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 8           4.860e-01  1.993e+00  ╭ g = -0.46423 - #2
#                                   ├ h = -0.46423 + #2
#                                   ├ p1 = [-0.91324]
#                                   ╰ alphas = [0.43597, -0.88044, -1.9027]
# 9           3.555e-01  3.129e-01  ╭ g = ((#2 - -0.79861) * -0.96597) + 0.77955
#                                   ├ h = 1.1418
#                                   ├ p1 = [-1.2196]
#                                   ╰ alphas = [-0.51676, -1.1823, -1.0684]
# 15          2.597e-01  5.233e-02  ╭ g = 0.64972 - ((-0.35134 + #2) - -0.93304)
#                                   ├ h = (#2 - #1) - -1.6857
#                                   ├ p1 = [-1.5259]
#                                   ╰ alphas = [-0.86885, 0.62923, 0.091147]
# 16          8.788e-02  1.084e+00  ╭ g = (((-0.28088 - #2) + (0.41255 - #2)) + #1) - #2
#                                   ├ h = -0.29474
#                                   ├ p1 = [-0.3148]
#                                   ╰ alphas = [-0.93287, 1.0192, -1.8959]
# 18          7.831e-02  5.760e-02  ╭ g = ((((1.8966 - #2) + (2.5912 - #2)) + #1) - #2) - -1.92
#                                   ├ h = -0.56223
#                                   ├ p1 = [-0.82666]
#                                   ╰ alphas = [-0.87771, 0.92835, -2.0644]
# 20          7.077e-02  5.065e-02  ╭ g = #1 + -3.2155
#                                   ├ h = (((-0.16103 - #2) + #2) + -1.203) + ((-1.3576 - #2) + 0....
#                                   21396)
#                                   ├ p1 = [-1.5189]
#                                   ╰ alphas = [-0.9129, -0.92421, -0.88949]
# 22          6.719e-02  2.592e-02  ╭ g = (#1 + -1.1537) - 2.0545
#                                   ├ h = ((-0.17974 - (#2 + #2)) + -1.2215) + ((-1.3763 - #2) + 0...
#                                   .19524)
#                                   ├ p1 = [-1.5276]
#                                   ╰ alphas = [-0.90507, -0.91682, -0.87844]
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.620e+01
# Progress: 14 / 2000 total iterations (0.700%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 8           4.860e-01  1.993e+00  ╭ g = -0.46423 - #2
#                                   ├ h = -0.46423 + #2
#                                   ├ p1 = [-0.91324]
#                                   ╰ alphas = [0.43597, -0.88044, -1.9027]
# 9           3.555e-01  3.129e-01  ╭ g = ((#2 - -0.79861) * -0.96597) + 0.77955
#                                   ├ h = 1.1418
#                                   ├ p1 = [-1.2196]
#                                   ╰ alphas = [-0.51676, -1.1823, -1.0684]
# 15          1.967e-01  9.866e-02  ╭ g = #1 + (-0.35949 + #1)
#                                   ├ h = (#2 * 0.54749) + (1.2759 * -0.35949)
#                                   ├ p1 = [-1.0686]
#                                   ╰ alphas = [-0.82974, -0.35066, -0.76477]
# 16          8.788e-02  8.055e-01  ╭ g = (((-0.28088 - #2) + (0.41255 - #2)) + #1) - #2
#                                   ├ h = -0.29474
#                                   ├ p1 = [-0.3148]
#                                   ╰ alphas = [-0.93287, 1.0192, -1.8959]
# 18          4.896e-02  2.924e-01  ╭ g = (#2 - (#1 + -0.39629)) * 1.2383
#                                   ├ h = (#2 - (#1 + -0.1914)) * 1.2108
#                                   ├ p1 = [0.93831]
#                                   ╰ alphas = [-0.86295, 0.88316, 1.2171]
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.720e+01
# Progress: 18 / 2000 total iterations (0.900%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 8           4.860e-01  1.993e+00  ╭ g = -0.46423 - #2
#                                   ├ h = -0.46423 + #2
#                                   ├ p1 = [-0.91324]
#                                   ╰ alphas = [0.43597, -0.88044, -1.9027]
# 9           3.555e-01  3.129e-01  ╭ g = ((#2 - -0.79861) * -0.96597) + 0.77955
#                                   ├ h = 1.1418
#                                   ├ p1 = [-1.2196]
#                                   ╰ alphas = [-0.51676, -1.1823, -1.0684]
# 15          1.967e-01  9.866e-02  ╭ g = #1 + (-0.35949 + #1)
#                                   ├ h = (#2 * 0.54749) + (1.2759 * -0.35949)
#                                   ├ p1 = [-1.0686]
#                                   ╰ alphas = [-0.82974, -0.35066, -0.76477]
# 16          8.788e-02  8.055e-01  ╭ g = (((-0.28088 - #2) + (0.41255 - #2)) + #1) - #2
#                                   ├ h = -0.29474
#                                   ├ p1 = [-0.3148]
#                                   ╰ alphas = [-0.93287, 1.0192, -1.8959]
# 17          6.622e-02  2.830e-01  ╭ g = ((-0.27293 + #1) * (-0.6904 - #1)) + (0.18284 - #1)
#                                   ├ h = -0.27293 - -1.8296
#                                   ├ p1 = [0.58705]
#                                   ╰ alphas = [-0.90047, 2.0479, 0.63539]
# 18          4.896e-02  3.019e-01  ╭ g = (#2 - (#1 + -0.39629)) * 1.2383
#                                   ├ h = (#2 - (#1 + -0.1914)) * 1.2108
#                                   ├ p1 = [0.93831]
#                                   ╰ alphas = [-0.86295, 0.88316, 1.2171]
# 28          4.509e-02  8.228e-03  ╭ g = (((#1 + -0.26576) * (-0.67322 - #1)) + 0.18915) - #1
#                                   ├ h = (#1 + (((#1 - -1.8144) + 0.65232) + #1)) + -0.28817
#                                   ├ p1 = [0.79608]
#                                   ╰ alphas = [-0.85017, 2.048, 0.65152]
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.810e+01
# Progress: 22 / 2000 total iterations (1.100%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 8           4.860e-01  1.993e+00  ╭ g = -0.46423 - #2
#                                   ├ h = -0.46423 + #2
#                                   ├ p1 = [-0.91324]
#                                   ╰ alphas = [0.43597, -0.88044, -1.9027]
# 9           3.555e-01  3.129e-01  ╭ g = ((#2 - -0.79861) * -0.96597) + 0.77955
#                                   ├ h = 1.1418
#                                   ├ p1 = [-1.2196]
#                                   ╰ alphas = [-0.51676, -1.1823, -1.0684]
# 14          7.581e-02  3.091e-01  ╭ g = (#2 ^ #1) * -0.082648
#                                   ├ h = (#2 ^ #1) * 0.36069
#                                   ├ p1 = [-1.4491]
#                                   ╰ alphas = [-0.94063, -0.80523, 0.23012]
# 17          6.622e-02  4.508e-02  ╭ g = ((-0.27293 + #1) * (-0.6904 - #1)) + (0.18284 - #1)
#                                   ├ h = -0.27293 - -1.8296
#                                   ├ p1 = [0.58705]
#                                   ╰ alphas = [-0.90047, 2.0479, 0.63539]
# 18          4.896e-02  3.019e-01  ╭ g = (#2 - (#1 + -0.39629)) * 1.2383
#                                   ├ h = (#2 - (#1 + -0.1914)) * 1.2108
#                                   ├ p1 = [0.93831]
#                                   ╰ alphas = [-0.86295, 0.88316, 1.2171]
# 28          4.509e-02  8.228e-03  ╭ g = (((#1 + -0.26576) * (-0.67322 - #1)) + 0.18915) - #1
#                                   ├ h = (#1 + (((#1 - -1.8144) + 0.65232) + #1)) + -0.28817
#                                   ├ p1 = [0.79608]
#                                   ╰ alphas = [-0.85017, 2.048, 0.65152]
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.040e+01
# Progress: 26 / 2000 total iterations (1.300%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 8           4.860e-01  1.993e+00  ╭ g = -0.46423 - #2
#                                   ├ h = -0.46423 + #2
#                                   ├ p1 = [-0.91324]
#                                   ╰ alphas = [0.43597, -0.88044, -1.9027]
# 9           3.555e-01  3.129e-01  ╭ g = ((#2 - -0.79861) * -0.96597) + 0.77955
#                                   ├ h = 1.1418
#                                   ├ p1 = [-1.2196]
#                                   ╰ alphas = [-0.51676, -1.1823, -1.0684]
# 12          2.785e-01  8.131e-02  ╭ g = (#1 + 0.042317) - #2
#                                   ├ h = #2 - #1
#                                   ├ p1 = [-2.8873]
#                                   ╰ alphas = [0.14696, -1.2536, -3.3545]
# 13          7.741e-02  1.280e+00  ╭ g = 28.207
#                                   ├ h = (#2 - ((#2 - 0.36647) + 2.9022)) + #1
#                                   ├ p1 = [-1.54]
#                                   ╰ alphas = [-0.94581, 0.62442, 0.076143]
# 14          7.581e-02  2.092e-02  ╭ g = (#2 ^ #1) * -0.082648
#                                   ├ h = (#2 ^ #1) * 0.36069
#                                   ├ p1 = [-1.4491]
#                                   ╰ alphas = [-0.94063, -0.80523, 0.23012]
# 17          6.622e-02  4.508e-02  ╭ g = ((-0.27293 + #1) * (-0.6904 - #1)) + (0.18284 - #1)
#                                   ├ h = -0.27293 - -1.8296
#                                   ├ p1 = [0.58705]
#                                   ╰ alphas = [-0.90047, 2.0479, 0.63539]
# 18          4.896e-02  3.019e-01  ╭ g = (#2 - (#1 + -0.39629)) * 1.2383
#                                   ├ h = (#2 - (#1 + -0.1914)) * 1.2108
#                                   ├ p1 = [0.93831]
#                                   ╰ alphas = [-0.86295, 0.88316, 1.2171]
# 28          4.509e-02  8.228e-03  ╭ g = (((#1 + -0.26576) * (-0.67322 - #1)) + 0.18915) - #1
#                                   ├ h = (#1 + (((#1 - -1.8144) + 0.65232) + #1)) + -0.28817
#                                   ├ p1 = [0.79608]
#                                   ╰ alphas = [-0.85017, 2.048, 0.65152]
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.450e+01
# Progress: 30 / 2000 total iterations (1.500%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 7           5.259e-01  2.277e+00  ╭ g = -0.46423 - 0.17498
#                                   ├ h = -0.46423 + #2
#                                   ├ p1 = [-0.91324]
#                                   ╰ alphas = [0.43597, -0.88044, -1.9027]
# 8           4.860e-01  7.876e-02  ╭ g = -0.46423 - #2
#                                   ├ h = -0.46423 + #2
#                                   ├ p1 = [-0.91324]
#                                   ╰ alphas = [0.43597, -0.88044, -1.9027]
# 9           3.555e-01  3.129e-01  ╭ g = ((#2 - -0.79861) * -0.96597) + 0.77955
#                                   ├ h = 1.1418
#                                   ├ p1 = [-1.2196]
#                                   ╰ alphas = [-0.51676, -1.1823, -1.0684]
# 11          1.337e-01  4.888e-01  ╭ g = 0.64972 - (#2 + (-0.35134 - -0.93304))
#                                   ├ h = -0.35134 - -0.85051
#                                   ├ p1 = [-1.5259]
#                                   ╰ alphas = [-0.86885, -0.56206, 0.091147]
# 12          7.342e-02  5.995e-01  ╭ g = (#1 - 2.056) + -1.1521
#                                   ├ h = (#1 * 1.9732) + -2.9692
#                                   ├ p1 = [-1.5505]
#                                   ╰ alphas = [-0.91104, -0.92335, -0.88797]
# 17          6.622e-02  2.066e-02  ╭ g = ((-0.27293 + #1) * (-0.6904 - #1)) + (0.18284 - #1)
#                                   ├ h = -0.27293 - -1.8296
#                                   ├ p1 = [0.58705]
#                                   ╰ alphas = [-0.90047, 2.0479, 0.63539]
# 18          4.896e-02  3.019e-01  ╭ g = (#2 - (#1 + -0.39629)) * 1.2383
#                                   ├ h = (#2 - (#1 + -0.1914)) * 1.2108
#                                   ├ p1 = [0.93831]
#                                   ╰ alphas = [-0.86295, 0.88316, 1.2171]
# 28          4.509e-02  8.228e-03  ╭ g = (((#1 + -0.26576) * (-0.67322 - #1)) + 0.18915) - #1
#                                   ├ h = (#1 + (((#1 - -1.8144) + 0.65232) + #1)) + -0.28817
#                                   ├ p1 = [0.79608]
#                                   ╰ alphas = [-0.85017, 2.048, 0.65152]
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.160e+01
# Progress: 34 / 2000 total iterations (1.700%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 2           2.220e+00  7.971e+00  ╭ g = 0.068029
#                                   ├ h = 1.0424
#                                   ├ p1 = [-1.5259]
#                                   ╰ alphas = [-0.86885, 0.62923, 0.091147]
# 6           3.072e-01  4.944e-01  ╭ g = 0.64972 - 0.70082
#                                   ├ h = 0.70082 - -0.35134
#                                   ├ p1 = [-1.5259]
#                                   ╰ alphas = [-0.86885, 0.62923, 0.091147]
# 7           7.374e-02  1.427e+00  ╭ g = -0.31588 - (#2 + -0.31878)
#                                   ├ h = -0.17502
#                                   ├ p1 = [-1.3106]
#                                   ╰ alphas = [-0.92825, 0.67089, 0.12095]
# 12          7.342e-02  8.710e-04  ╭ g = (#1 - 2.056) + -1.1521
#                                   ├ h = (#1 * 1.9732) + -2.9692
#                                   ├ p1 = [-1.5505]
#                                   ╰ alphas = [-0.91104, -0.92335, -0.88797]
# 17          6.622e-02  2.066e-02  ╭ g = ((-0.27293 + #1) * (-0.6904 - #1)) + (0.18284 - #1)
#                                   ├ h = -0.27293 - -1.8296
#                                   ├ p1 = [0.58705]
#                                   ╰ alphas = [-0.90047, 2.0479, 0.63539]
# 18          4.896e-02  3.019e-01  ╭ g = (#2 - (#1 + -0.39629)) * 1.2383
#                                   ├ h = (#2 - (#1 + -0.1914)) * 1.2108
#                                   ├ p1 = [0.93831]
#                                   ╰ alphas = [-0.86295, 0.88316, 1.2171]
# 28          4.509e-02  8.228e-03  ╭ g = (((#1 + -0.26576) * (-0.67322 - #1)) + 0.18915) - #1
#                                   ├ h = (#1 + (((#1 - -1.8144) + 0.65232) + #1)) + -0.28817
#                                   ├ p1 = [0.79608]
#                                   ╰ alphas = [-0.85017, 2.048, 0.65152]
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.310e+01
# Progress: 39 / 2000 total iterations (1.950%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 2           6.523e-02  7.971e+00  ╭ g = 3.0711
#                                   ├ h = 2.9169
#                                   ├ p1 = [0.69872]
#                                   ╰ alphas = [-0.88628, -2.3301, -0.83851]
# 18          4.896e-02  1.793e-02  ╭ g = (#2 - (#1 + -0.39629)) * 1.2383
#                                   ├ h = (#2 - (#1 + -0.1914)) * 1.2108
#                                   ├ p1 = [0.93831]
#                                   ╰ alphas = [-0.86295, 0.88316, 1.2171]
# 19          4.258e-02  1.396e-01  ╭ g = ((#1 - (#1 + -0.50146)) - 1.5631) - #2
#                                   ├ h = (#2 + -2.4906) + #2
#                                   ├ p1 = [0.83624]
#                                   ╰ alphas = [-0.86763, 2.0444, 1.1105]
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.970e+01
# Progress: 44 / 2000 total iterations (2.200%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 2           6.523e-02  7.971e+00  ╭ g = 3.0711
#                                   ├ h = 2.9169
#                                   ├ p1 = [0.69872]
#                                   ╰ alphas = [-0.88628, -2.3301, -0.83851]
# 15          4.305e-02  3.197e-02  ╭ g = (0.21352 - #1) + ((#1 + -0.27292) * (-0.71841 - #1))
#                                   ├ h = 1.5422
#                                   ├ p1 = [0.82365]
#                                   ╰ alphas = [-0.86834, 2.0655, 0.86861]
# 19          4.258e-02  2.729e-03  ╭ g = ((#1 - (#1 + -0.50146)) - 1.5631) - #2
#                                   ├ h = (#2 + -2.4906) + #2
#                                   ├ p1 = [0.83624]
#                                   ╰ alphas = [-0.86763, 2.0444, 1.1105]
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.070e+01
# Progress: 49 / 2000 total iterations (2.450%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 2           6.523e-02  7.971e+00  ╭ g = 3.0711
#                                   ├ h = 2.9169
#                                   ├ p1 = [0.69872]
#                                   ╰ alphas = [-0.88628, -2.3301, -0.83851]
# 15          4.305e-02  3.197e-02  ╭ g = (0.21352 - #1) + ((#1 + -0.27292) * (-0.71841 - #1))
#                                   ├ h = 1.5422
#                                   ├ p1 = [0.82365]
#                                   ╰ alphas = [-0.86834, 2.0655, 0.86861]
# 19          4.258e-02  2.729e-03  ╭ g = ((#1 - (#1 + -0.50146)) - 1.5631) - #2
#                                   ├ h = (#2 + -2.4906) + #2
#                                   ├ p1 = [0.83624]
#                                   ╰ alphas = [-0.86763, 2.0444, 1.1105]
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.070e+01
# Progress: 53 / 2000 total iterations (2.650%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 2           6.523e-02  7.971e+00  ╭ g = 3.0711
#                                   ├ h = 2.9169
#                                   ├ p1 = [0.69872]
#                                   ╰ alphas = [-0.88628, -2.3301, -0.83851]
# 15          4.305e-02  3.197e-02  ╭ g = (0.21352 - #1) + ((#1 + -0.27292) * (-0.71841 - #1))
#                                   ├ h = 1.5422
#                                   ├ p1 = [0.82365]
#                                   ╰ alphas = [-0.86834, 2.0655, 0.86861]
# 19          4.258e-02  2.729e-03  ╭ g = ((#1 - (#1 + -0.50146)) - 1.5631) - #2
#                                   ├ h = (#2 + -2.4906) + #2
#                                   ├ p1 = [0.83624]
#                                   ╰ alphas = [-0.86763, 2.0444, 1.1105]
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.080e+01
# Progress: 57 / 2000 total iterations (2.850%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 2           4.676e-02  7.971e+00  ╭ g = 0.53803
#                                   ├ h = 0.068186
#                                   ├ p1 = [0.91986]
#                                   ╰ alphas = [-0.89438, -2.0041, 1.325]
# 15          4.305e-02  6.364e-03  ╭ g = (0.21352 - #1) + ((#1 + -0.27292) * (-0.71841 - #1))
#                                   ├ h = 1.5422
#                                   ├ p1 = [0.82365]
#                                   ╰ alphas = [-0.86834, 2.0655, 0.86861]
# 19          4.258e-02  2.729e-03  ╭ g = ((#1 - (#1 + -0.50146)) - 1.5631) - #2
#                                   ├ h = (#2 + -2.4906) + #2
#                                   ├ p1 = [0.83624]
#                                   ╰ alphas = [-0.86763, 2.0444, 1.1105]
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.980e+01
# Progress: 61 / 2000 total iterations (3.050%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 2           4.676e-02  7.971e+00  ╭ g = 0.53803
#                                   ├ h = 0.068186
#                                   ├ p1 = [0.91986]
#                                   ╰ alphas = [-0.89438, -2.0041, 1.325]
# 15          4.305e-02  6.364e-03  ╭ g = (0.21352 - #1) + ((#1 + -0.27292) * (-0.71841 - #1))
#                                   ├ h = 1.5422
#                                   ├ p1 = [0.82365]
#                                   ╰ alphas = [-0.86834, 2.0655, 0.86861]
# 19          4.194e-02  6.557e-03  ╭ g = (#1 - -0.51225) - (1.5065 - #2)
#                                   ├ h = (-2.4312 - #1) + (#2 - #1)
#                                   ├ p1 = [0.85028]
#                                   ╰ alphas = [-0.88175, 2.0461, 1.1573]
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.040e+01
# Progress: 65 / 2000 total iterations (3.250%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 2           4.676e-02  7.971e+00  ╭ g = 0.53803
#                                   ├ h = 0.068186
#                                   ├ p1 = [0.91986]
#                                   ╰ alphas = [-0.89438, -2.0041, 1.325]
# 15          4.305e-02  6.364e-03  ╭ g = (0.21352 - #1) + ((#1 + -0.27292) * (-0.71841 - #1))
#                                   ├ h = 1.5422
#                                   ├ p1 = [0.82365]
#                                   ╰ alphas = [-0.86834, 2.0655, 0.86861]
# 19          4.194e-02  6.557e-03  ╭ g = (#1 - -0.51225) - (1.5065 - #2)
#                                   ├ h = (-2.4312 - #1) + (#2 - #1)
#                                   ├ p1 = [0.85028]
#                                   ╰ alphas = [-0.88175, 2.0461, 1.1573]
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.020e+01
# Progress: 71 / 2000 total iterations (3.550%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 2           4.676e-02  7.971e+00  ╭ g = 0.53803
#                                   ├ h = 0.068186
#                                   ├ p1 = [0.91986]
#                                   ╰ alphas = [-0.89438, -2.0041, 1.325]
# 15          4.305e-02  6.364e-03  ╭ g = (0.21352 - #1) + ((#1 + -0.27292) * (-0.71841 - #1))
#                                   ├ h = 1.5422
#                                   ├ p1 = [0.82365]
#                                   ╰ alphas = [-0.86834, 2.0655, 0.86861]
# 19          4.194e-02  6.557e-03  ╭ g = (#1 - -0.51225) - (1.5065 - #2)
#                                   ├ h = (-2.4312 - #1) + (#2 - #1)
#                                   ├ p1 = [0.85028]
#                                   ╰ alphas = [-0.88175, 2.0461, 1.1573]
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.150e+01
# Progress: 75 / 2000 total iterations (3.750%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 2           4.676e-02  7.971e+00  ╭ g = 0.53803
#                                   ├ h = 0.068186
#                                   ├ p1 = [0.91986]
#                                   ╰ alphas = [-0.89438, -2.0041, 1.325]
# 15          4.305e-02  6.364e-03  ╭ g = (0.21352 - #1) + ((#1 + -0.27292) * (-0.71841 - #1))
#                                   ├ h = 1.5422
#                                   ├ p1 = [0.82365]
#                                   ╰ alphas = [-0.86834, 2.0655, 0.86861]
# 17          4.292e-02  1.471e-03  ╭ g = ((#1 - #1) + 1.9129) + (#1 + -0.0023023)
#                                   ├ h = #1 - #1
#                                   ├ p1 = [0.84785]
#                                   ╰ alphas = [-0.87094, 2.0645, 0.956]
# 18          4.288e-02  1.115e-03  ╭ g = (0.21352 - #1) + ((#1 + -0.27292) * (-0.71841 - #1))
#                                   ├ h = 1.5422 + #1
#                                   ├ p1 = [0.82365]
#                                   ╰ alphas = [-0.86834, 2.0655, 0.86861]
# 19          4.194e-02  2.217e-02  ╭ g = (#1 - -0.51225) - (1.5065 - #2)
#                                   ├ h = (-2.4312 - #1) + (#2 - #1)
#                                   ├ p1 = [0.85028]
#                                   ╰ alphas = [-0.88175, 2.0461, 1.1573]
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.160e+01
# Progress: 80 / 2000 total iterations (4.000%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 2           4.676e-02  7.971e+00  ╭ g = 0.53803
#                                   ├ h = 0.068186
#                                   ├ p1 = [0.91986]
#                                   ╰ alphas = [-0.89438, -2.0041, 1.325]
# 15          4.305e-02  6.364e-03  ╭ g = (0.21352 - #1) + ((#1 + -0.27292) * (-0.71841 - #1))
#                                   ├ h = 1.5422
#                                   ├ p1 = [0.82365]
#                                   ╰ alphas = [-0.86834, 2.0655, 0.86861]
# 17          4.292e-02  1.471e-03  ╭ g = ((#1 - #1) + 1.9129) + (#1 + -0.0023023)
#                                   ├ h = #1 - #1
#                                   ├ p1 = [0.84785]
#                                   ╰ alphas = [-0.87094, 2.0645, 0.956]
# 18          4.288e-02  1.115e-03  ╭ g = (0.21352 - #1) + ((#1 + -0.27292) * (-0.71841 - #1))
#                                   ├ h = 1.5422 + #1
#                                   ├ p1 = [0.82365]
#                                   ╰ alphas = [-0.86834, 2.0655, 0.86861]
# 19          4.194e-02  2.217e-02  ╭ g = (#1 - -0.51225) - (1.5065 - #2)
#                                   ├ h = (-2.4312 - #1) + (#2 - #1)
#                                   ├ p1 = [0.85028]
#                                   ╰ alphas = [-0.88175, 2.0461, 1.1573]
# 25          4.193e-02  1.532e-05  ╭ g = ((#1 - (#2 * (#2 + -0.48676))) + -2.1298) - #2
#                                   ├ h = #2 + ((#2 * #1) + -2.4113)
#                                   ├ p1 = [0.85645]
#                                   ╰ alphas = [-0.8771, 2.0459, 1.1528]
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.140e+01
# Progress: 86 / 2000 total iterations (4.300%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 2           4.676e-02  7.971e+00  ╭ g = 0.53803
#                                   ├ h = 0.068186
#                                   ├ p1 = [0.91986]
#                                   ╰ alphas = [-0.89438, -2.0041, 1.325]
# 12          4.310e-02  8.159e-03  ╭ g = #1 - (#2 - 1.3962)
#                                   ├ h = #1 - #1
#                                   ├ p1 = [0.85028]
#                                   ╰ alphas = [-0.88175, 2.0461, 1.1573]
# 15          4.270e-02  3.131e-03  ╭ g = 1.3046 - #2
#                                   ├ h = #1 - (#1 + (#1 - #1))
#                                   ├ p1 = [0.85028]
#                                   ╰ alphas = [-0.88175, 2.0461, 1.1573]
# 17          4.256e-02  1.593e-03  ╭ g = #1 - (-0.091658 - (1.3046 - #2))
#                                   ├ h = #1 - (#1 + #1)
#                                   ├ p1 = [0.85028]
#                                   ╰ alphas = [-0.88175, 2.0461, 1.1573]
# 19          4.194e-02  7.396e-03  ╭ g = (#1 - -0.51225) - (1.5065 - #2)
#                                   ├ h = (-2.4312 - #1) + (#2 - #1)
#                                   ├ p1 = [0.85028]
#                                   ╰ alphas = [-0.88175, 2.0461, 1.1573]
# 25          4.193e-02  1.532e-05  ╭ g = ((#1 - (#2 * (#2 + -0.48676))) + -2.1298) - #2
#                                   ├ h = #2 + ((#2 * #1) + -2.4113)
#                                   ├ p1 = [0.85645]
#                                   ╰ alphas = [-0.8771, 2.0459, 1.1528]
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.050e+01
# Progress: 90 / 2000 total iterations (4.500%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 2           4.676e-02  7.971e+00  ╭ g = 0.53803
#                                   ├ h = 0.068186
#                                   ├ p1 = [0.91986]
#                                   ╰ alphas = [-0.89438, -2.0041, 1.325]
# 12          4.310e-02  8.159e-03  ╭ g = #1 - (#2 - 1.3962)
#                                   ├ h = #1 - #1
#                                   ├ p1 = [0.85028]
#                                   ╰ alphas = [-0.88175, 2.0461, 1.1573]
# 15          4.270e-02  3.131e-03  ╭ g = 1.3046 - #2
#                                   ├ h = #1 - (#1 + (#1 - #1))
#                                   ├ p1 = [0.85028]
#                                   ╰ alphas = [-0.88175, 2.0461, 1.1573]
# 17          4.256e-02  1.593e-03  ╭ g = #1 - (-0.091658 - (1.3046 - #2))
#                                   ├ h = #1 - (#1 + #1)
#                                   ├ p1 = [0.85028]
#                                   ╰ alphas = [-0.88175, 2.0461, 1.1573]
# 19          4.194e-02  7.396e-03  ╭ g = (#1 - -0.51225) - (1.5065 - #2)
#                                   ├ h = (-2.4312 - #1) + (#2 - #1)
#                                   ├ p1 = [0.85028]
#                                   ╰ alphas = [-0.88175, 2.0461, 1.1573]
# 25          4.193e-02  1.532e-05  ╭ g = ((#1 - (#2 * (#2 + -0.48676))) + -2.1298) - #2
#                                   ├ h = #2 + ((#2 * #1) + -2.4113)
#                                   ├ p1 = [0.85645]
#                                   ╰ alphas = [-0.8771, 2.0459, 1.1528]
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.020e+01
# Progress: 94 / 2000 total iterations (4.700%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 2           4.676e-02  7.971e+00  ╭ g = 0.53803
#                                   ├ h = 0.068186
#                                   ├ p1 = [0.91986]
#                                   ╰ alphas = [-0.89438, -2.0041, 1.325]
# 12          4.310e-02  8.159e-03  ╭ g = #1 - (#2 - 1.3962)
#                                   ├ h = #1 - #1
#                                   ├ p1 = [0.85028]
#                                   ╰ alphas = [-0.88175, 2.0461, 1.1573]
# 15          4.270e-02  3.131e-03  ╭ g = 1.3046 - #2
#                                   ├ h = #1 - (#1 + (#1 - #1))
#                                   ├ p1 = [0.85028]
#                                   ╰ alphas = [-0.88175, 2.0461, 1.1573]
# 17          4.256e-02  1.593e-03  ╭ g = #1 - (-0.091658 - (1.3046 - #2))
#                                   ├ h = #1 - (#1 + #1)
#                                   ├ p1 = [0.85028]
#                                   ╰ alphas = [-0.88175, 2.0461, 1.1573]
# 19          4.194e-02  7.396e-03  ╭ g = (#1 - -0.51225) - (1.5065 - #2)
#                                   ├ h = (-2.4312 - #1) + (#2 - #1)
#                                   ├ p1 = [0.85028]
#                                   ╰ alphas = [-0.88175, 2.0461, 1.1573]
# 25          4.193e-02  1.532e-05  ╭ g = ((#1 - (#2 * (#2 + -0.48676))) + -2.1298) - #2
#                                   ├ h = #2 + ((#2 * #1) + -2.4113)
#                                   ├ p1 = [0.85645]
#                                   ╰ alphas = [-0.8771, 2.0459, 1.1528]
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.090e+01
# Progress: 98 / 2000 total iterations (4.900%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 2           4.676e-02  7.971e+00  ╭ g = 0.53803
#                                   ├ h = 0.068186
#                                   ├ p1 = [0.91986]
#                                   ╰ alphas = [-0.89438, -2.0041, 1.325]
# 12          4.310e-02  8.159e-03  ╭ g = #1 - (#2 - 1.3962)
#                                   ├ h = #1 - #1
#                                   ├ p1 = [0.85028]
#                                   ╰ alphas = [-0.88175, 2.0461, 1.1573]
# 15          4.270e-02  3.131e-03  ╭ g = 1.3046 - #2
#                                   ├ h = #1 - (#1 + (#1 - #1))
#                                   ├ p1 = [0.85028]
#                                   ╰ alphas = [-0.88175, 2.0461, 1.1573]
# 17          4.256e-02  1.593e-03  ╭ g = #1 - (-0.091658 - (1.3046 - #2))
#                                   ├ h = #1 - (#1 + #1)
#                                   ├ p1 = [0.85028]
#                                   ╰ alphas = [-0.88175, 2.0461, 1.1573]
# 19          4.194e-02  7.396e-03  ╭ g = (#1 - -0.51225) - (1.5065 - #2)
#                                   ├ h = (-2.4312 - #1) + (#2 - #1)
#                                   ├ p1 = [0.85028]
#                                   ╰ alphas = [-0.88175, 2.0461, 1.1573]
# 25          4.189e-02  2.021e-04  ╭ g = ((#1 - ((#2 + -0.49487) * #2)) + -2.1086) - #2
#                                   ├ h = #2 + ((#2 * #2) + -2.4298)
#                                   ├ p1 = [0.86336]
#                                   ╰ alphas = [-0.87543, 2.0445, 1.1839]
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.930e+01
# Progress: 102 / 2000 total iterations (5.100%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 2           4.676e-02  7.971e+00  ╭ g = 0.53803
#                                   ├ h = 0.068186
#                                   ├ p1 = [0.91986]
#                                   ╰ alphas = [-0.89438, -2.0041, 1.325]
# 12          4.310e-02  8.159e-03  ╭ g = #1 - (#2 - 1.3962)
#                                   ├ h = #1 - #1
#                                   ├ p1 = [0.85028]
#                                   ╰ alphas = [-0.88175, 2.0461, 1.1573]
# 15          4.270e-02  3.131e-03  ╭ g = 1.3046 - #2
#                                   ├ h = #1 - (#1 + (#1 - #1))
#                                   ├ p1 = [0.85028]
#                                   ╰ alphas = [-0.88175, 2.0461, 1.1573]
# 17          4.256e-02  1.593e-03  ╭ g = #1 - (-0.091658 - (1.3046 - #2))
#                                   ├ h = #1 - (#1 + #1)
#                                   ├ p1 = [0.85028]
#                                   ╰ alphas = [-0.88175, 2.0461, 1.1573]
# 19          4.194e-02  7.396e-03  ╭ g = (#1 - -0.51225) - (1.5065 - #2)
#                                   ├ h = (-2.4312 - #1) + (#2 - #1)
#                                   ├ p1 = [0.85028]
#                                   ╰ alphas = [-0.88175, 2.0461, 1.1573]
# 25          4.189e-02  2.021e-04  ╭ g = ((#1 - ((#2 + -0.49487) * #2)) + -2.1086) - #2
#                                   ├ h = #2 + ((#2 * #2) + -2.4298)
#                                   ├ p1 = [0.86336]
#                                   ╰ alphas = [-0.87543, 2.0445, 1.1839]
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.090e+01
# Progress: 106 / 2000 total iterations (5.300%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 2           4.676e-02  7.971e+00  ╭ g = 0.53803
#                                   ├ h = 0.068186
#                                   ├ p1 = [0.91986]
#                                   ╰ alphas = [-0.89438, -2.0041, 1.325]
# 11          4.300e-02  9.328e-03  ╭ g = #1 - (-0.56872 - 1.3962)
#                                   ├ h = #1 - #1
#                                   ├ p1 = [0.85028]
#                                   ╰ alphas = [-0.88175, 2.0461, 1.1573]
# 14          4.234e-02  5.163e-03  ╭ g = (-0.25702 * #2) - (#2 - 1.3962)
#                                   ├ h = #1 - #1
#                                   ├ p1 = [0.85028]
#                                   ╰ alphas = [-0.88175, 2.0461, 1.1573]
# 19          4.194e-02  1.904e-03  ╭ g = (#1 - -0.51225) - (1.5065 - #2)
#                                   ├ h = (-2.4312 - #1) + (#2 - #1)
#                                   ├ p1 = [0.85028]
#                                   ╰ alphas = [-0.88175, 2.0461, 1.1573]
# 25          4.189e-02  2.021e-04  ╭ g = ((#1 - ((#2 + -0.49487) * #2)) + -2.1086) - #2
#                                   ├ h = #2 + ((#2 * #2) + -2.4298)
#                                   ├ p1 = [0.86336]
#                                   ╰ alphas = [-0.87543, 2.0445, 1.1839]
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.110e+01
# Progress: 112 / 2000 total iterations (5.600%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 2           4.676e-02  7.971e+00  ╭ g = 0.53803
#                                   ├ h = 0.068186
#                                   ├ p1 = [0.91986]
#                                   ╰ alphas = [-0.89438, -2.0041, 1.325]
# 11          4.300e-02  9.328e-03  ╭ g = #1 - (-0.56872 - 1.3962)
#                                   ├ h = #1 - #1
#                                   ├ p1 = [0.85028]
#                                   ╰ alphas = [-0.88175, 2.0461, 1.1573]
# 14          4.234e-02  5.163e-03  ╭ g = (-0.25702 * #2) - (#2 - 1.3962)
#                                   ├ h = #1 - #1
#                                   ├ p1 = [0.85028]
#                                   ╰ alphas = [-0.88175, 2.0461, 1.1573]
# 19          4.194e-02  1.904e-03  ╭ g = (#1 - -0.51225) - (1.5065 - #2)
#                                   ├ h = (-2.4312 - #1) + (#2 - #1)
#                                   ├ p1 = [0.85028]
#                                   ╰ alphas = [-0.88175, 2.0461, 1.1573]
# 20          4.188e-02  1.313e-03  ╭ g = #2 + ((#2 - 1.4316) - #2)
#                                   ├ h = (-2.1948 - #1) + (#2 + #1)
#                                   ├ p1 = [0.85753]
#                                   ╰ alphas = [-0.87752, 2.0576, 1.1677]
# 23          4.180e-02  6.770e-04  ╭ g = #2 + (#2 - (1.4679 - (#2 * #2)))
#                                   ├ h = (-2.2923 - #1) + (#2 + #1)
#                                   ├ p1 = [0.85828]
#                                   ╰ alphas = [-0.87708, 2.0426, 1.2]
# 30          4.178e-02  7.170e-05  ╭ g = (#1 - (#2 * (#2 + -0.5185))) + ((-2.0111 - #2) - (#1 + 0...
#                                   .20631))
#                                   ├ h = (#2 + (#2 * #2)) + -2.4966
#                                   ├ p1 = [0.8596]
#                                   ╰ alphas = [-0.88103, 2.0363, 1.1762]
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════

# %%
print(model.equations_["equation"][8])
# Out:
# f = ((((#1 ^ -0.87698907) * #2) + (0.12443335 - ((#2 * 3.3415005) + -0.08294956))) - 0.22508325) + -0.93462837; p0 = [0.70336616]; p1 = [0.023773357, 0.45307383, 1.6200533]

# %%
ells = np.array([l for l in range(2, 5000)])

# %%
fig, ax = plt.subplots(1, 1, figsize = (5, 5))

# Final Fit

def lensing_tail_fit(ell, ombh2, omch2):
    """
    Cl_lensed(l) = lensing_tail_fit(l; ombh2, omch2) * Cl_unlensed(l)

    Inputs:
        ell:   Single value of l or numpy array of l values to be evaluated.
        ombh2: Baryon Density Parameter for Cosmology of interest.
        omch2: Dark Matter Density Parameter for Cosmology of interest.

    Outputs: 
        val: Lensing tail for specified ell(s). Returns same type of object as input ell (single value or numpy array).
    
    """
    
    beta_1 = 0.83
    beta_2 = 0.4531
    beta_3 = 1.62
    
    # Sigmoid
    L = (1 + np.exp(-(ell-beta_3*2000)/100))**(-1)

    # Exponent
    alpha = (ombh2**-0.877) * (ombh2 + omch2) - 3.342*(ombh2 + omch2) - 1.118

    #
    L *= (beta_1*(ell/beta_2)**alpha - 1)

    L += 1
    
    return L


# Fit % Error for 100 Cosmologies
for ind in range(0, 100):
    ax.semilogx(ells, 100*np.abs(example_fit(ells, pars[ind, 1], pars[ind, 2]) - lensed[ind]/unlensed[ind])/(lensed[ind]/unlensed[ind]), "r", label='new fitting formula')


ax.set_xlim(3000, 5000)
ax.set_xlabel("$\ell$")

ax.set_ylabel("% error against CAMB lensing tail")


handles, labels = fig.gca().get_legend_handles_labels()
newLabels, newHandles = [], []
for handle, label in zip(handles, labels):
  if label not in newLabels:
    newLabels.append(label)
    newHandles.append(handle)
ax.legend(newHandles, newLabels)
# Out:
# <>:29: SyntaxWarning: invalid escape sequence '\e'
# <>:29: SyntaxWarning: invalid escape sequence '\e'
# /var/folders/x5/mt3y0q2n65zcpd0hz503pkx00000gn/T/ipykernel_52710/1074212189.py:29: SyntaxWarning: invalid escape sequence '\e'
#   ax.set_xlabel("$\ell$")
# /var/folders/x5/mt3y0q2n65zcpd0hz503pkx00000gn/T/ipykernel_52710/1074212189.py:29: SyntaxWarning: invalid escape sequence '\e'
#   ax.set_xlabel("$\ell$")
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 fig, ax = plt.subplots(1, 1, figsize = (5, 5))
#       3 # Final Fit
#       5 def lensing_tail_fit(ell, ombh2, omch2):
#
# NameError: name 'plt' is not defined

# %%
# PLOTS BELOW vvvvv

# %%
pars = camb.set_params(H0 = 67.4, ombh2 = 0.0224, omch2 = 0.12, lmax=5000)
results = camb.get_results(pars)
powers = results.get_cmb_power_spectra(pars, CMB_unit='muK')
fiducial_lensed = powers['total'][2:5000, 0]
fiducial_unlensed = powers['unlensed_total'][2:5000, 0]
ells = np.array([l for l in range(2, 5000)])

from cycler import cycler
line_cycler   = (cycler(color=["#E69F00", "#56B4E9", "#009E73", "#0072B2", "#D55E00", "#CC79A7", "#F0E442"]) +
                 cycler(linestyle=["-", "--", "-.", ":", "-", "--", "-."]))

# %%
fig, ax = plt.subplots(1, 1)

fiducial_lensing = fiducial_lensed/fiducial_unlensed

#ax.loglog(ells, fiducial_lensing)

past_ells = 1000
n_ells = 4998 - past_ells

def moving_average(x):
    val = np.convolve(x, np.ones(500), 'valid') / 500
    return val

fiducial_smoothed = np.apply_along_axis(moving_average, axis = 0, arr = fiducial_lensing[1000:])

fiducial_smoothed = np.concatenate((fiducial_lensing[:1250], fiducial_smoothed))
fiducial_smoothed = np.concatenate((fiducial_smoothed, fiducial_lensing[-249:]))

#ax.loglog(ells, fiducial_smoothed)


plt.rc("axes", prop_cycle=line_cycler)


plt.plot(ells, fiducial_lensing, label = f"Original", lw=2.5)
plt.plot(ells, fiducial_smoothed, label = f"Smoothed", lw=2.5)


#plt.loglog([0.007, 0.007],[7e-5, 1], label = "$k_{eq}$")
#plt.semilogx(a.khs*a.h, a.GA_transfer, label = f"GA")
#plt.semilogx(a.khs*a.h, a.BBKS_transfer, label = f"BBKS")
#plt.semilogx(a.khs*a.h, a.EH_transfer, label = f"EH")
plt.grid(alpha=0.15, color='lightgray', lw=2.5)

plt.xlim(1250, 4750)

plt.ylabel(r"$C_{\ell}^{lensed}/C_{\ell}^{unlensed}$", fontsize = 16, fontname="Helvetica")
plt.xlabel("$\ell$", fontsize = 16, fontname="Helvetica")
plt.legend(loc="upper left", fontsize = 14, borderpad = 1)

plt.tick_params(axis='x', labelsize=16)
plt.tick_params(axis='y', labelsize=16)

plt.savefig("fiducial_smoothing.pdf", format="pdf", bbox_inches='tight')
# Out:
# <>:38: SyntaxWarning: invalid escape sequence '\e'
# <>:38: SyntaxWarning: invalid escape sequence '\e'
# /var/folders/x5/mt3y0q2n65zcpd0hz503pkx00000gn/T/ipykernel_22909/2010798905.py:38: SyntaxWarning: invalid escape sequence '\e'
#   plt.xlabel("$\ell$", fontsize = 16, fontname="Helvetica")
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.

# %%
ombh2vals = np.array([0.012, 0.02])
omch2vals = np.array([0.1, 0.13])

par_arr = []
lensing_tails = []

for _ombh2 in ombh2vals:
    for _omch2 in omch2vals:

        par_arr.append((_ombh2, _omch2))
        
        pars = camb.set_params(H0 = 67.4, ombh2 = _ombh2, omch2 = _omch2, lmax=5000)
        results = camb.get_results(pars)
        powers = results.get_cmb_power_spectra(pars, CMB_unit='muK')
        lensing_tails.append(powers['total'][2:5000, 0]/ powers['unlensed_total'][2:5000, 0])

# %%
plt.rc("axes", prop_cycle=line_cycler)


plt.semilogx(ells, fiducial_lensing, label = f"CAMB", lw=2.5)

#plt.loglog([0.007, 0.007],[7e-5, 1], label = "$k_{eq}$")
#plt.semilogx(a.khs*a.h, a.GA_transfer, label = f"GA")
#plt.semilogx(a.khs*a.h, a.BBKS_transfer, label = f"BBKS")
#plt.semilogx(a.khs*a.h, a.EH_transfer, label = f"EH")
plt.grid(alpha=0.15, color='lightgray', lw=2.5)

plt.ylabel(r"$C_{\ell}^{lensed}/C_{\ell}^{unlensed}$", fontsize = 16, fontname="Helvetica")
plt.xlabel("$\ell$", fontsize = 16, fontname="Helvetica")
#plt.legend()

plt.tick_params(axis='x', labelsize=16)
plt.tick_params(axis='y', labelsize=16)

plt.savefig("fiducial_lensing_tail.pdf", format="pdf", bbox_inches='tight')
# Out:
# <>:13: SyntaxWarning: invalid escape sequence '\e'
# <>:13: SyntaxWarning: invalid escape sequence '\e'
# /var/folders/x5/mt3y0q2n65zcpd0hz503pkx00000gn/T/ipykernel_22909/794045992.py:13: SyntaxWarning: invalid escape sequence '\e'
#   plt.xlabel("$\ell$", fontsize = 16, fontname="Helvetica")

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 5))#, sharey=True)

plt.rc("axes", prop_cycle=line_cycler)

ax[0].semilogx(ells, fiducial_lensing, lw=2.5)

for i, lensings in enumerate(lensing_tails):
    if i == 0:
        ax[1].plot(ells, example_fit(ells, par_arr[i][0], par_arr[i][1]), linestyle = ":", color = "k",label = rf"Fit", lw=2.5)
    else:
        ax[1].plot(ells, example_fit(ells, par_arr[i][0], par_arr[i][1]), linestyle = ":", color = "k", lw=2.5)#, label = rf"$\Omega_bh^2=${round(par_arr[i][0], 4)}, $\Omega_ch^2=${round(par_arr[i][1], 3)}", lw=2.5)
    
    ax[1].plot(ells, lensings, label = rf"$\Omega_bh^2=${round(par_arr[i][0], 4)}, $\Omega_ch^2=${round(par_arr[i][1], 3)}", lw=2.5)



ax[0].grid(alpha=0.15, color='lightgray', lw=2.5)

ax[0].set_ylabel("$C_{\ell}^{lensed}/C_{\ell}^{unlensed}$", fontsize = 20, fontname="Helvetica")
ax[0].set_xlabel("$\ell$", fontsize = 16, fontname="Helvetica")
#plt.legend()

ax[0].tick_params(axis='x', labelsize=16)
ax[0].tick_params(axis='y', labelsize=16)

ax[1].grid(alpha=0.15, color='lightgray', lw=2.5)

ax[0].set_xlim(0, 1000)
ax[1].set_xlim(3100, 5000)

ax[1].set_ylabel(r"$C_{\ell}^{lensed}/C_{\ell}^{unlensed}$", fontsize=20, fontname="Helvetica")
ax[1].set_xlabel("$\ell$", fontsize = 16, fontname="Helvetica")
ax[1].legend(loc = "upper left")

ax[1].tick_params(axis='x', labelsize=16)
ax[1].tick_params(axis='y', labelsize=16)

fig.tight_layout()
#plt.savefig("sample_lensing_tails.pdf", format="pdf", bbox_inches='tight')
# Out:
# <>:19: SyntaxWarning: invalid escape sequence '\e'
# <>:20: SyntaxWarning: invalid escape sequence '\e'
# <>:32: SyntaxWarning: invalid escape sequence '\e'
# <>:19: SyntaxWarning: invalid escape sequence '\e'
# <>:20: SyntaxWarning: invalid escape sequence '\e'
# <>:32: SyntaxWarning: invalid escape sequence '\e'
# /var/folders/x5/mt3y0q2n65zcpd0hz503pkx00000gn/T/ipykernel_22909/2468407756.py:19: SyntaxWarning: invalid escape sequence '\e'
#   ax[0].set_ylabel("$C_{\ell}^{lensed}/C_{\ell}^{unlensed}$", fontsize = 20, fontname="Helvetica")
# /var/folders/x5/mt3y0q2n65zcpd0hz503pkx00000gn/T/ipykernel_22909/2468407756.py:20: SyntaxWarning: invalid escape sequence '\e'
#   ax[0].set_xlabel("$\ell$", fontsize = 16, fontname="Helvetica")
# /var/folders/x5/mt3y0q2n65zcpd0hz503pkx00000gn/T/ipykernel_22909/2468407756.py:32: SyntaxWarning: invalid escape sequence '\e'
#   ax[1].set_xlabel("$\ell$", fontsize = 16, fontname="Helvetica")
# /var/folders/x5/mt3y0q2n65zcpd0hz503pkx00000gn/T/ipykernel_22909/2468407756.py:28: UserWarning: Attempt to set non-positive xlim on a log-scaled axis will be ignored.
#   ax[0].set_xlim(0, 1000)

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 5))#, sharey=True)

plt.rc("axes", prop_cycle=line_cycler)

ax[0].semilogx(ells, fiducial_lensing, lw=2.5)

for i, lensings in enumerate(lensing_tails):
    ax[1].plot(ells, lensings, label = rf"$\Omega_bh^2=${round(par_arr[i][0], 4)}, $\Omega_ch^2=${round(par_arr[i][1], 3)}", lw=2.5)

ax[0].grid(alpha=0.15, color='lightgray', lw=2.5)

ax[0].set_ylabel("$C_{\ell}^{lensed}/C_{\ell}^{unlensed}$", fontsize = 20, fontname="Helvetica")
ax[0].set_xlabel("$\ell$", fontsize = 16, fontname="Helvetica")
#plt.legend()

ax[0].tick_params(axis='x', labelsize=16)
ax[0].tick_params(axis='y', labelsize=16)

ax[1].grid(alpha=0.15, color='lightgray', lw=2.5)

ax[1].set_xlim(2000, 5000)

ax[1].set_ylabel(r"$C_{\ell}^{lensed}/C_{\ell}^{unlensed}$", fontsize=20, fontname="Helvetica")
ax[1].set_xlabel("$\ell$", fontsize = 16, fontname="Helvetica")
ax[1].legend(loc = "upper left")

ax[1].tick_params(axis='x', labelsize=16)
ax[1].tick_params(axis='y', labelsize=16)

fig.tight_layout()
plt.savefig("sample_lensing_tails.pdf", format="pdf", bbox_inches='tight')

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 5))#, sharey=True)

plt.rc("axes", prop_cycle=line_cycler)


ax[0].plot(ells, fiducial_lensing, lw=2.5, label = "CAMB")
ax[0].plot(ells, example_fit(ells, 0.0224, 0.12), lw=2.5, label = "SR")


for i, lensings in enumerate(lensing_tails):
    if i == 0 or i == 2 or i == 3:
        omb = par_arr[i][0]
        omc = par_arr[i][1]
    
        fit = example_fit(ells, omb, omc)
        
        ax[1].plot(ells, 100*np.abs(fit-lensings)/lensings, label = rf"$\Omega_bh^2=${round(omb, 4)}, $\Omega_ch^2=${round(omc, 3)}", lw=2.5)

ax[0].grid(alpha=0.15, color='lightgray', lw=2.5)

ax[0].set_ylabel("$L(\ell)$", fontsize = 16, fontname="Helvetica")
ax[0].set_xlabel("$\ell$", fontsize = 16, fontname="Helvetica")

ax[0].tick_params(axis='x', labelsize=16)
ax[0].tick_params(axis='y', labelsize=16)

ax[0].set_xlim(2000, 5000)
ax[1].set_xlim(2000, 5000)

ax[1].grid(alpha=0.15, color='lightgray', lw=2.5)


ax[1].set_ylabel(r"$100\times\frac{|L_{SR}(\ell) - L_{CAMB}(\ell)|}{L_{CAMB}(\ell)}$", fontsize=20, fontname="Helvetica")
ax[1].set_xlabel("$\ell$", fontsize = 16, fontname="Helvetica")
ax[0].legend(fontsize = 14)

ax[1].legend(fontsize = 14)

ax[1].tick_params(axis='x', labelsize=16)
ax[1].tick_params(axis='y', labelsize=16)

fig.tight_layout()
plt.savefig("lensing_tail_errors.pdf", format="pdf", bbox_inches='tight')
# Out:
# <>:21: SyntaxWarning: invalid escape sequence '\e'
# <>:22: SyntaxWarning: invalid escape sequence '\e'
# <>:34: SyntaxWarning: invalid escape sequence '\e'
# <>:21: SyntaxWarning: invalid escape sequence '\e'
# <>:22: SyntaxWarning: invalid escape sequence '\e'
# <>:34: SyntaxWarning: invalid escape sequence '\e'
# /var/folders/x5/mt3y0q2n65zcpd0hz503pkx00000gn/T/ipykernel_22909/1902582090.py:21: SyntaxWarning: invalid escape sequence '\e'
#   ax[0].set_ylabel("$L(\ell)$", fontsize = 16, fontname="Helvetica")
# /var/folders/x5/mt3y0q2n65zcpd0hz503pkx00000gn/T/ipykernel_22909/1902582090.py:22: SyntaxWarning: invalid escape sequence '\e'
#   ax[0].set_xlabel("$\ell$", fontsize = 16, fontname="Helvetica")
# /var/folders/x5/mt3y0q2n65zcpd0hz503pkx00000gn/T/ipykernel_22909/1902582090.py:34: SyntaxWarning: invalid escape sequence '\e'
#   ax[1].set_xlabel("$\ell$", fontsize = 16, fontname="Helvetica")

# %%
def average_error(omb, omc):
    ells_2000 = np.array([ell for ell in range(3200, 5000)])

    n_ells = len(ells_2000)
    
    pars = camb.set_params(H0 = 67.4, ombh2 = omb, omch2 = omc, lmax=5000)
    results = camb.get_results(pars)
    powers = results.get_cmb_power_spectra(pars, CMB_unit='muK')
    
    camb_lensing = powers['total'][3200:5000, 0]/ powers['unlensed_total'][3200:5000, 0]

    fit = example_fit(ells_2000, omb, omc)

    errs = 100*np.abs(fit-camb_lensing)/camb_lensing

    return errs.sum()/n_ells

# %%
ombh2vals = np.array([0.012, 0.02])
omch2vals = np.array([0.1, 0.13])

for omb in ombh2vals:
    for omc in omch2vals:
        print(f"omb = {omb}, omc = {omc}, avg_error: {average_error(omb, omc)}")
# Out:
# omb = 0.012, omc = 0.1, avg_error: 10.387440350156373
# omb = 0.012, omc = 0.13, avg_error: 11.133553088442032
# omb = 0.02, omc = 0.1, avg_error: 7.914416596151798
# omb = 0.02, omc = 0.13, avg_error: 8.489997723414

# %%
ombh2_vals_meshgrid = np.linspace(0.006, 0.04, 10)
omch2_vals_meshgrid = np.linspace(0.05, 0.3, 10)

lensing_avg_error = np.zeros((10, 10))

for i, omb in enumerate(ombh2_vals_meshgrid):
    for j, omc in enumerate(omch2_vals_meshgrid):
        
        print(f"currently: {10*i + j + 1}/100")
        
        lensing_avg_error[i, j] = average_error(omb, omc)
# Out:
# currently: 1/100
# currently: 2/100
# currently: 3/100
# currently: 4/100
# currently: 5/100
# currently: 6/100
# currently: 7/100
# currently: 8/100
# currently: 9/100
# currently: 10/100
# currently: 11/100
# currently: 12/100
# currently: 13/100
# currently: 14/100
# currently: 15/100
# currently: 16/100
# currently: 17/100
# currently: 18/100
# currently: 19/100
# currently: 20/100
# currently: 21/100
# currently: 22/100
# currently: 23/100
# currently: 24/100
# currently: 25/100
# currently: 26/100
# currently: 27/100
# currently: 28/100
# currently: 29/100
# currently: 30/100
# currently: 31/100
# currently: 32/100
# currently: 33/100
# currently: 34/100
# currently: 35/100
# currently: 36/100
# currently: 37/100
# currently: 38/100
# currently: 39/100
# currently: 40/100
# currently: 41/100
# currently: 42/100
# currently: 43/100
# currently: 44/100
# currently: 45/100
# currently: 46/100
# currently: 47/100
# currently: 48/100
# currently: 49/100
# currently: 50/100
# currently: 51/100
# currently: 52/100
# currently: 53/100
# currently: 54/100
# currently: 55/100
# currently: 56/100
# currently: 57/100
# currently: 58/100
# currently: 59/100
# currently: 60/100
# currently: 61/100
# currently: 62/100
# currently: 63/100
# currently: 64/100
# currently: 65/100
# currently: 66/100
# currently: 67/100
# currently: 68/100
# currently: 69/100
# currently: 70/100
# currently: 71/100
# currently: 72/100
# currently: 73/100
# currently: 74/100
# currently: 75/100
# currently: 76/100
# currently: 77/100
# currently: 78/100
# currently: 79/100
# currently: 80/100
# currently: 81/100
# currently: 82/100
# currently: 83/100
# currently: 84/100
# currently: 85/100
# currently: 86/100
# currently: 87/100
# currently: 88/100
# currently: 89/100
# currently: 90/100
# currently: 91/100
# currently: 92/100
# currently: 93/100
# currently: 94/100
# currently: 95/100
# currently: 96/100
# currently: 97/100
# currently: 98/100
# currently: 99/100
# currently: 100/100

# %%
x, y = np.meshgrid(omch2_vals_meshgrid, ombh2_vals_meshgrid)

fig, ax = plt.subplots(1, 1)

z1 = lensing_avg_error

c = ax.pcolormesh(y, x, z1, cmap='Blues', vmax = 100)
ax.axis([y.min(), y.max(), x.min(), x.max() ])

#ax.set_title('EH', fontsize = 16, fontname="Helvetica")

ax.tick_params(axis='x', labelsize=16)
ax.tick_params(axis='y', labelsize=16)

fig.tight_layout()

fig.colorbar(c, ax=ax)

ax.set_ylabel(r"$\Omega_c h^2$", fontsize = 16, fontname="Helvetica")
ax.set_xlabel(r"$\Omega_b h^2$", fontsize = 16, fontname="Helvetica")

plt.savefig("lensing_tail_errors_grid.pdf", format="pdf", bbox_inches='tight')

# %%
pars     = np.load('CL_data/parameter_H0_vary.npy')  # [H0, ombh2, omch2 ] x 100
lensed   = np.load('CL_data/lensed_H0_vary.npy')     # [C_2, ..., C_5000] x 100 (lensed)
unlensed = np.load('CL_data/unlensed_H0_vary.npy')     # [C_2, ..., C_5000] x 100 (unlensed)

# %%
lensing_tails = lensed/unlensed

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 5))#, sharey=True)

plt.rc("axes", prop_cycle=line_cycler)

ax[0].semilogx(ells, fiducial_lensing, lw=2.5)

for i, lensings in enumerate(lensing_tails):
    if i <=5 :
        ax[1].plot(ells, lensings, label = rf"$H0=${round(pars[i, 0], 2)}", lw=2.5)

ax[0].grid(alpha=0.15, color='lightgray', lw=2.5)

ax[0].set_ylabel("$C_{\ell}^{lensed}/C_{\ell}^{unlensed}$", fontsize = 20, fontname="Helvetica")
ax[0].set_xlabel("$\ell$", fontsize = 16, fontname="Helvetica")
#plt.legend()

ax[0].tick_params(axis='x', labelsize=16)
ax[0].tick_params(axis='y', labelsize=16)

ax[1].grid(alpha=0.15, color='lightgray', lw=2.5)

ax[0].set_xlim(0, 1000)
ax[1].set_xlim(2000, 5000)

ax[1].set_ylabel(r"$C_{\ell}^{lensed}/C_{\ell}^{unlensed}$", fontsize=20, fontname="Helvetica")
ax[1].set_xlabel("$\ell$", fontsize = 16, fontname="Helvetica")
ax[1].legend(loc = "upper left")

ax[1].tick_params(axis='x', labelsize=16)
ax[1].tick_params(axis='y', labelsize=16)

fig.tight_layout()
#plt.savefig("sample_lensing_tails.pdf", format="pdf", bbox_inches='tight')
# Out:
# <>:13: SyntaxWarning: invalid escape sequence '\e'
# <>:14: SyntaxWarning: invalid escape sequence '\e'
# <>:26: SyntaxWarning: invalid escape sequence '\e'
# <>:13: SyntaxWarning: invalid escape sequence '\e'
# <>:14: SyntaxWarning: invalid escape sequence '\e'
# <>:26: SyntaxWarning: invalid escape sequence '\e'
# /var/folders/x5/mt3y0q2n65zcpd0hz503pkx00000gn/T/ipykernel_22909/202245794.py:13: SyntaxWarning: invalid escape sequence '\e'
#   ax[0].set_ylabel("$C_{\ell}^{lensed}/C_{\ell}^{unlensed}$", fontsize = 20, fontname="Helvetica")
# /var/folders/x5/mt3y0q2n65zcpd0hz503pkx00000gn/T/ipykernel_22909/202245794.py:14: SyntaxWarning: invalid escape sequence '\e'
#   ax[0].set_xlabel("$\ell$", fontsize = 16, fontname="Helvetica")
# /var/folders/x5/mt3y0q2n65zcpd0hz503pkx00000gn/T/ipykernel_22909/202245794.py:26: SyntaxWarning: invalid escape sequence '\e'
#   ax[1].set_xlabel("$\ell$", fontsize = 16, fontname="Helvetica")
# /var/folders/x5/mt3y0q2n65zcpd0hz503pkx00000gn/T/ipykernel_22909/202245794.py:22: UserWarning: Attempt to set non-positive xlim on a log-scaled axis will be ignored.
#   ax[0].set_xlim(0, 1000)
